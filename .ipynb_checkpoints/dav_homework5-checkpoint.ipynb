# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
def import_data(index):
  data = pd.read_csv('data/ans.csv')

  x = data['x%d' % (index)]
  y = data['y%d' % (index)]
  x = np.asarray(x)
  y = np.asarray(y)
  return x.flatten(), y.flatten()

# %%
def statistics(x, y):
  x_mean = np.mean(x)
  x_var = np.var(x)
  y_mean = np.mean(y)
  y_var = np.var(y)
  slope, intercept, correlation, p_value, std_err = stats.linregress(x,y)
  determination = correlation**2

  return x_mean, x_var, y_mean, y_var, correlation, slope, intercept, determination

# %%
from IPython.core.display import HTML
CSS = """
.output {
    align-items: center;
}
"""
HTML('<style>{}</style>'.format(CSS))
# Out:
# <style>
# .output {
#     align-items: center;
# }
# </style>

# %%
from IPython.display import HTML, display
import tabulate

def table(index):
    x, y = import_data(index)
    x_mean, x_var, y_mean, y_var, correlation, slope, intercept, determination = statistics(x, y)
    table = [['Mean of x%d' % (index),int(x_mean),'exact'],
             ['Sample variance of x%d' % (index),int(x_var),'exact'],
             ['Mean of y%d' % (index),np.round(y_mean,3),'to 3 decimal places'],
             ['Sample variance of y%d' % (index),np.round(y_var,3),'to 3 decimal places'],
             ['Correlation between x%d and y%d' % (index, index),
              np.round(correlation,3),'to 3 decimal places'],
             ['Linear regression line', 'y%d=%s+%sx%d' % (index, str(np.round(intercept,2))+'0', str(np.round(slope,3))+'00', index), 'to 2 and 3 decimal places, respectively'],
             ['Coefficient of determination of the linear regression',np.round(determination,2),'to 2 decimal places']]
    display(HTML(tabulate.tabulate(table, headers=['Property','Value','Accuracy'], tablefmt='html')))

# %%
for i in range(1,5):
    table(i)
# Out:
# <table>
# <thead>
# <tr><th>Property                                             </th><th>Value          </th><th>Accuracy                               </th></tr>
# </thead>
# <tbody>
# <tr><td>Mean of x1                                           </td><td>9              </td><td>exact                                  </td></tr>
# <tr><td>Sample variance of x1                                </td><td>10             </td><td>exact                                  </td></tr>
# <tr><td>Mean of y1                                           </td><td>7.501          </td><td>to 3 decimal places                    </td></tr>
# <tr><td>Sample variance of y1                                </td><td>3.752          </td><td>to 3 decimal places                    </td></tr>
# <tr><td>Correlation between x1 and y1                        </td><td>0.816          </td><td>to 3 decimal places                    </td></tr>
# <tr><td>Linear regression line                               </td><td>y1=3.00+0.500x1</td><td>to 2 and 3 decimal places, respectively</td></tr>
# <tr><td>Coefficient of determination of the linear regression</td><td>0.67           </td><td>to 2 decimal places                    </td></tr>
# </tbody>
# </table>
# <table>
# <thead>
# <tr><th>Property                                             </th><th>Value          </th><th>Accuracy                               </th></tr>
# </thead>
# <tbody>
# <tr><td>Mean of x2                                           </td><td>9              </td><td>exact                                  </td></tr>
# <tr><td>Sample variance of x2                                </td><td>10             </td><td>exact                                  </td></tr>
# <tr><td>Mean of y2                                           </td><td>7.501          </td><td>to 3 decimal places                    </td></tr>
# <tr><td>Sample variance of y2                                </td><td>3.752          </td><td>to 3 decimal places                    </td></tr>
# <tr><td>Correlation between x2 and y2                        </td><td>0.816          </td><td>to 3 decimal places                    </td></tr>
# <tr><td>Linear regression line                               </td><td>y2=3.00+0.500x2</td><td>to 2 and 3 decimal places, respectively</td></tr>
# <tr><td>Coefficient of determination of the linear regression</td><td>0.67           </td><td>to 2 decimal places                    </td></tr>
# </tbody>
# </table>
# <table>
# <thead>
# <tr><th>Property                                             </th><th>Value          </th><th>Accuracy                               </th></tr>
# </thead>
# <tbody>
# <tr><td>Mean of x3                                           </td><td>9              </td><td>exact                                  </td></tr>
# <tr><td>Sample variance of x3                                </td><td>10             </td><td>exact                                  </td></tr>
# <tr><td>Mean of y3                                           </td><td>7.5            </td><td>to 3 decimal places                    </td></tr>
# <tr><td>Sample variance of y3                                </td><td>3.748          </td><td>to 3 decimal places                    </td></tr>
# <tr><td>Correlation between x3 and y3                        </td><td>0.816          </td><td>to 3 decimal places                    </td></tr>
# <tr><td>Linear regression line                               </td><td>y3=3.00+0.500x3</td><td>to 2 and 3 decimal places, respectively</td></tr>
# <tr><td>Coefficient of determination of the linear regression</td><td>0.67           </td><td>to 2 decimal places                    </td></tr>
# </tbody>
# </table>
# <table>
# <thead>
# <tr><th>Property                                             </th><th>Value          </th><th>Accuracy                               </th></tr>
# </thead>
# <tbody>
# <tr><td>Mean of x4                                           </td><td>9              </td><td>exact                                  </td></tr>
# <tr><td>Sample variance of x4                                </td><td>10             </td><td>exact                                  </td></tr>
# <tr><td>Mean of y4                                           </td><td>7.501          </td><td>to 3 decimal places                    </td></tr>
# <tr><td>Sample variance of y4                                </td><td>3.748          </td><td>to 3 decimal places                    </td></tr>
# <tr><td>Correlation between x4 and y4                        </td><td>0.817          </td><td>to 3 decimal places                    </td></tr>
# <tr><td>Linear regression line                               </td><td>y4=3.00+0.500x4</td><td>to 2 and 3 decimal places, respectively</td></tr>
# <tr><td>Coefficient of determination of the linear regression</td><td>0.67           </td><td>to 2 decimal places                    </td></tr>
# </tbody>
# </table>

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 200
mpl.rcParams['axes.linewidth'] = 0.3

# %%
def subplot_axes(ax, i, j):
  ax.set_xlim(0,20)
  ax.set_ylim(0,14)
  ax.set_xticks(np.arange(0,20,2))
  ax.set_yticks(np.arange(0,14,2))
  ax.text(-0.1, 0.5, 'y'+str(2*i+j+1), va='center', ha='center', size=7,
          color='black', transform=ax.transAxes, rotation='vertical')
  ax.text(0.5, -0.18, 'x'+str(2*i+j+1), va='center', ha='center', size=7,
          color='black', transform=ax.transAxes)
  ax.tick_params(axis='x', colors='black', labelsize=7.0, length=2.0)
  ax.tick_params(axis='y', colors='black', labelsize=7.0, length=2.0)

# %%
def scatter_plot(ax, i, j):
  x, y = import_data(2*i + j + 1)
  ax.scatter(x, y, s=15, alpha=0.8, c='orange', edgecolors='red', linewidths=0.5)

# %%
def line_plot(ax):
  x = np.linspace(0, 20, 10)
  y = 0.5*x + 3
  ax.plot(x, y, linewidth=0.8, c='blue')

# %%
fig, ax = plt.subplots(2,2)
fig.patch.set_facecolor('xkcd:white')

for i in range(len(ax)):
  for j in range(len(ax[i])):
    subplot_axes(ax[i][j],i,j)
    scatter_plot(ax[i][j],i,j)
    line_plot(ax[i][j])

plt.tight_layout(pad=1.0)

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data/ans2.tsv', sep='\t')

# %%
datasets = np.asarray(data['dataset'])
datasets = np.unique(datasets)

# %%
def import_dataset(dataset):
  data = pd.read_csv('data/ans2.tsv', sep='\t')
  x, y = [], []
  for index, row in data.iterrows():
    if row['dataset'] == dataset:
      x.append(row['x'])
      y.append(row['y'])
  return np.asarray(x), np.asarray(y)

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 200
mpl.rcParams['axes.linewidth'] = 0.3

# %%
def plots(datasets, ax):
  for i in range(len(datasets)):
    x, y = import_dataset(datasets[i])
    index_1 = int((i-i%4)/4)
    index_2 = int(i%4)
    ax[index_1,index_2].plot(x,y, linewidth=0.5)
    ax[index_1,index_2].set_xticks(np.arange(0, 110, 25))
    ax[index_1,index_2].set_yticks(np.arange(0, 110, 25))
    ax[index_1,index_2].tick_params(axis='x', colors='black', labelsize=5.0, length=2.0)
    ax[index_1,index_2].tick_params(axis='y', colors='black', labelsize=5.0, length=2.0)
    ax[index_1,index_2].grid(linewidth=0.2)

    ax[index_1,index_2].text(0.5, 1.1, datasets[i], va='center', ha='center', size=5.0,
          color='black', transform=ax[index_1,index_2].transAxes)

    if index_1 < 2:
      ax[index_1,index_2].set_xticklabels([])
    if index_1 == 2 and index_2 == 0:
      ax[index_1,index_2].set_xticklabels([])
    if index_2 != 0:
      ax[index_1,index_2].set_yticklabels([])

  # clear redundant subplots
  for i in range(1,4):
    ax[3,i].spines['top'].set_visible(False)
    ax[3,i].spines['bottom'].set_visible(False)
    ax[3,i].spines['right'].set_visible(False)
    ax[3,i].spines['left'].set_visible(False)
    ax[3,i].set_xticks([])
    ax[3,i].set_yticks([])

# %%
fig, ax = plt.subplots(4,4)
fig.patch.set_facecolor('xkcd:white')
plots(datasets, ax)
plt.tight_layout(pad=0.5)
