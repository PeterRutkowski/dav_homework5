# %%
import pandas as pd
import numpy as np
from scipy import stats
from IPython.display import HTML, display
import tabulate   
from statistics import variance

# %%
from IPython.core.display import HTML
CSS = """
.output {
    align-items: center;
}
"""
HTML('<style>{}</style>'.format(CSS))
# Out:
# <style>
# .output {
#     align-items: center;
# }
# </style>

# %% [markdown]
# <center>Data analysis and visualisation - Lab 8 Homework - Piotr Rutkowski</center>

# %% [markdown]
# <center>Task 1</center>

# %%
def import_data(index):
  data = pd.read_csv('data/ans.csv')

  x = data['x%d' % (index)]
  y = data['y%d' % (index)]
  x = np.asarray(x)
  y = np.asarray(y)
  return x.flatten(), y.flatten()

# %%
def statistics1(x, y):
  x_mean = np.mean(x)
  x_var = variance(x)
  y_mean = np.mean(y)
  y_var = variance(y)
  slope, intercept, correlation, p_value, std_err = stats.linregress(x,y)
  determination = correlation**2

  return x_mean, x_var, y_mean, y_var, correlation, slope, intercept, determination

# %%
for i in range(1,5):
    x, y = import_data(i)
    print(statistics1(x, y))

# %%
table = [['Mean of x',9,'exact'],
         ['Sample variance of x', 11,'exact'],
         ['Mean of y', '7.50','to 2 decimal places'],
         ['Sample variance of y', 4.125,'±0.003'],
         ['Correlation between x and y',0.8163,'±0.0002'],
         ['Linear regression line', 'y=%s+%sx' %('3.00','0.500'), 'to 2 and 3 decimal places, respectively'],
         ['Coefficient of determination of the linear regression',0.6665,'±0.0003']]
display(HTML(tabulate.tabulate(table, headers=['Property','Value','Accuracy'], tablefmt='html')))
# Out:
# <table>
# <thead>
# <tr><th>Property                                             </th><th>Value        </th><th>Accuracy                               </th></tr>
# </thead>
# <tbody>
# <tr><td>Mean of x                                            </td><td>9            </td><td>exact                                  </td></tr>
# <tr><td>Sample variance of x                                 </td><td>11           </td><td>exact                                  </td></tr>
# <tr><td>Mean of y                                            </td><td>7.50         </td><td>to 2 decimal places                    </td></tr>
# <tr><td>Sample variance of y                                 </td><td>4.125        </td><td>±0.003                                 </td></tr>
# <tr><td>Correlation between x and y                          </td><td>0.8163       </td><td>±0.0002                                </td></tr>
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 200
mpl.rcParams['axes.linewidth'] = 0.3

# %%
def subplot_axes(ax, i, j):
  ax.set_xlim(0,20)
  ax.set_ylim(0,14)
  ax.set_xticks(np.arange(0,20,2))
  ax.set_yticks(np.arange(0,14,2))
  ax.text(-0.1, 0.5, 'y'+str(2*i+j+1), va='center', ha='center', size=7,
          color='black', transform=ax.transAxes, rotation='vertical')
  ax.text(0.5, -0.18, 'x'+str(2*i+j+1), va='center', ha='center', size=7,
          color='black', transform=ax.transAxes)
  ax.tick_params(axis='x', colors='black', labelsize=7.0, length=2.0)
  ax.tick_params(axis='y', colors='black', labelsize=7.0, length=2.0)

# %%
def scatter_plot(ax, i, j):
  x, y = import_data(2*i + j + 1)
  ax.scatter(x, y, s=15, alpha=0.8, c='orange', edgecolors='red', linewidths=0.5)

# %%
def line_plot(ax):
  x = np.linspace(0, 20, 10)
  y = 0.5*x + 3
  ax.plot(x, y, linewidth=0.8, c='blue')

# %%
fig, ax = plt.subplots(2,2)
fig.patch.set_facecolor('xkcd:white')

for i in range(len(ax)):
  for j in range(len(ax[i])):
    subplot_axes(ax[i][j],i,j)
    scatter_plot(ax[i][j],i,j)
    line_plot(ax[i][j])

plt.tight_layout(pad=1.0)

# %% [markdown]
# <center>Task 2</center>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data/ans2.tsv', sep='\t')

# %%
datasets = np.asarray(data['dataset'])
datasets = np.unique(datasets)

# %%
def import_dataset(dataset):
  data = pd.read_csv('data/ans2.tsv', sep='\t')
  x, y = [], []
  for index, row in data.iterrows():
    if row['dataset'] == dataset:
      x.append(row['x'])
      y.append(row['y'])
  return np.asarray(x), np.asarray(y)

# %%
def statistics2(x, y):
    x_mean, x_sd = np.mean(x), np.std(x)
    y_mean, y_sd = np.mean(y), np.std(y)
    slope, intercept, correlation, p_value, std_err = stats.linregress(x,y)

    return np.round(x_mean,3), np.round(y_mean,3), np.round(x_sd,3), np.round(y_sd,3), np.round(correlation,3)

# %%
for dataset in datasets:
    x, y = import_dataset(dataset)
    print(statistics2(x, y))

# %%
table = [['Mean of x',54.265,'±0.005'],
         ['Mean of y', 47.835,'±0.005'],
         ['SD of x', 16.706,'±0.005'],
         ['SD of y', '26.840','±0.005'],
         ['Corr', -0.065, '±0.005']]
display(HTML(tabulate.tabulate(table, headers=['Property','Value','Accuracy (up to 3 places)'], tablefmt='html')))
# Out:
# <table>
# <thead>
# <tr><th>Property  </th><th style="text-align: right;">  Value</th><th>Accuracy (up to 3 places)  </th></tr>
# </thead>
# <tbody>
# <tr><td>Mean of x </td><td style="text-align: right;"> 54.265</td><td>±0.005                     </td></tr>
# <tr><td>Mean of y </td><td style="text-align: right;"> 47.835</td><td>±0.005                     </td></tr>
# <tr><td>SD of x   </td><td style="text-align: right;"> 16.706</td><td>±0.005                     </td></tr>
# <tr><td>SD of y   </td><td style="text-align: right;"> 26.84 </td><td>±0.005                     </td></tr>
# <tr><td>Corr      </td><td style="text-align: right;"> -0.065</td><td>±0.005                     </td></tr>
# </tbody>
# </table>

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 200
mpl.rcParams['axes.linewidth'] = 0.3

# %%
def plots(datasets, ax):
  for i in range(len(datasets)):
    x, y = import_dataset(datasets[i])
    index_1 = int((i-i%4)/4)
    index_2 = int(i%4)
    ax[index_1,index_2].scatter(x, y, s=5, alpha=0.8, c='orange', edgecolors='red', linewidths=0.5)
    
    ax[index_1,index_2].set_xticks(np.arange(0, 110, 25))
    ax[index_1,index_2].set_yticks(np.arange(0, 110, 25))
    ax[index_1,index_2].tick_params(axis='x', colors='black', labelsize=5.0, length=2.0)
    ax[index_1,index_2].tick_params(axis='y', colors='black', labelsize=5.0, length=2.0)
    ax[index_1,index_2].grid(linewidth=0.2)

    ax[index_1,index_2].text(0.5, 1.1, datasets[i], va='center', ha='center', size=5.0,
          color='black', transform=ax[index_1,index_2].transAxes)

    if index_1 < 2:
      ax[index_1,index_2].set_xticklabels([])
    if index_1 == 2 and index_2 == 0:
      ax[index_1,index_2].set_xticklabels([])
    if index_2 != 0:
      ax[index_1,index_2].set_yticklabels([])

  # clear redundant subplots
  for i in range(1,4):
    ax[3,i].spines['top'].set_visible(False)
    ax[3,i].spines['bottom'].set_visible(False)
    ax[3,i].spines['right'].set_visible(False)
    ax[3,i].spines['left'].set_visible(False)
    ax[3,i].set_xticks([])
    ax[3,i].set_yticks([])

# %%
fig, ax = plt.subplots(4,4)
fig.patch.set_facecolor('xkcd:white')
plots(datasets, ax)
plt.tight_layout(pad=0.5)
